# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/peter/Desktop/DOI - Mai/Capstone/product.csv', index_col=None)

# %%
# Check to see if there are any missing values in our data set
df.isnull().any()
# Out:
# satisfaction_level        False
# discount_rate             False
# number_order              False
# reward_point              False
# days_since_prior_order    False
# complaint                 False
# reorder                   False
# pick_up                   False
# category                  False
# cost                      False
# dtype: bool

# %%
# Get a quick overview of what we are dealing with in our dataset
df.head()
# Out:
#    satisfaction_level  discount_rate  number_order  reward_point  \
# 0                0.38           0.53             2           157
# 1                0.80           0.86             5           262
# 2                0.11           0.88             7           272
# 3                0.72           0.87             5           223
# 4                0.37           0.52             2           159
#
#    days_since_prior_order  complaint  reorder  pick_up  category    cost
# 0                       3          0        1        0  vitamins     low
# 1                       6          0        1        0  vitamins  medium
# 2                       4          0        1        0  vitamins  medium
# 3                       5          0        1        0  vitamins     low
# 4                       3          0        1        0  vitamins     low

# %%
# The dataset contains 10 columns and 15000 observations
df.shape
# Out:
# (15000, 10)

# %%
# Move the reponse variable "turnover" to the front of the table
front = df['reorder']
df.drop(labels=['reorder'], axis=1,inplace = True)
df.insert(0, 'reorder', front)
df.head()
# Out:
#    reorder  satisfaction_level  discount_rate  number_order  reward_point  \
# 0        1                0.38           0.53             2           157
# 1        1                0.80           0.86             5           262
# 2        1                0.11           0.88             7           272
# 3        1                0.72           0.87             5           223
# 4        1                0.37           0.52             2           159
#
#    days_since_prior_order  complaint  pick_up  category    cost
# 0                       3          0        0  vitamins     low
# 1                       6          0        0  vitamins  medium
# 2                       4          0        0  vitamins  medium
# 3                       5          0        0  vitamins     low
# 4                       3          0        0  vitamins     low

# %%
# Check the type of our features. 
df.dtypes
# Out:
# reorder                     int64
# satisfaction_level        float64
# discount_rate             float64
# number_order                int64
# reward_point                int64
# days_since_prior_order      int64
# complaint                   int64
# pick_up                     int64
# category                   object
# cost                       object
# dtype: object

# %%
reorder_rate = df.reorder.value_counts() / len(df)
reorder_rate
#Looks like about 76% product reorder and 23% not reorder.
# Out:
# 0    0.761867
# 1    0.238133
# Name: reorder, dtype: float64

# %%
df.describe()
# Out:
#             reorder  satisfaction_level  discount_rate  number_order  \
# count  15000.000000        15000.000000   15000.000000  15000.000000
# mean       0.238133            0.612852       0.716113      3.803133
# std        0.425955            0.248633       0.171169      1.232590
# min        0.000000            0.090000       0.360000      2.000000
# 25%        0.000000            0.440000       0.560000      3.000000
# 50%        0.000000            0.640000       0.720000      4.000000
# 75%        0.000000            0.820000       0.870000      5.000000
# max        1.000000            1.000000       1.000000      7.000000
#
#        reward_point  days_since_prior_order     complaint       pick_up
# count  15000.000000            15000.000000  15000.000000  15000.000000
# mean     201.052133                3.498333      0.144667      0.021267
# std       49.941919                1.460139      0.351776      0.144277
# min       96.000000                2.000000      0.000000      0.000000
# 25%      156.000000                3.000000      0.000000      0.000000
# 50%      200.000000                3.000000      0.000000      0.000000
# 75%      245.000000                4.000000      0.000000      0.000000
# max      310.000000               10.000000      1.000000      1.000000

# %%
# Overview of summary (Reorder V.S. Non-reorder)
reorder_Summary = df.groupby('reorder')
reorder_Summary.mean()
# Out:
#          satisfaction_level  discount_rate  number_order  reward_point  \
# reorder
# 0                  0.666810       0.715473      3.786664    199.060203
# 1                  0.440224       0.718158      3.855823    207.424972
#
#          days_since_prior_order  complaint   pick_up
# reorder
# 0                      3.380032   0.175009  0.026251
# 1                      3.876820   0.047592  0.005319

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(y="cost", hue='reorder', data=df).set_title('Product cost and Reorder Distribution');

# %%
f, ax = plt.subplots(figsize=(15, 5))
sns.countplot(y="category", hue='reorder', data=df).set_title('Product Category and Reorder Distribution');

# %%
ax = sns.barplot(x="number_order", y="number_order", hue="reorder", data=df, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
ax = sns.barplot(x="days_since_prior_order", y="days_since_prior_order", hue="reorder", data=df, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
# Import KMeans Model
from sklearn.cluster import KMeans

# Graph and create 3 clusters of Customer Reorder
kmeans = KMeans(n_clusters=3,random_state=2)
kmeans.fit(df[df.reorder==1][["satisfaction_level","discount_rate"]])

kmeans_colors = ['green' if c == 0 else 'blue' if c == 2 else 'red' for c in kmeans.labels_]

fig = plt.figure(figsize=(10, 6))
plt.scatter(x="satisfaction_level",y="discount_rate", data=df[df.reorder==1],
            alpha=0.25,color = kmeans_colors)
plt.xlabel("Satisfaction")
plt.ylabel("Discount")
plt.scatter(x=kmeans.cluster_centers_[:,0],y=kmeans.cluster_centers_[:,1],color="black",marker="X",s=100)
plt.title("Clusters of Customer reorder")
plt.show()

# %%
total = len(df)
ax=pd.crosstab(df.category,df.reorder).plot(kind='bar',figsize=(8,8))
for p in ax.patches:
        ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+60))

# %%
dep_grp = df.groupby('category')
avg_hrs = []
yrs_spent = []
fig,ax = plt.subplots(4,1)
fig.set_figheight(20)
fig.set_figwidth(10)
for dept in dept_list:
    avg_hrs.append(dep_grp['reward_point'].mean().loc[dept])
    yrs_spent.append(dep_grp['days_since_prior_order'].mean().loc[dept])
ax[0].bar(dept_list,avg_hrs)
ax[0].set_title('Discount')
ax[0].set_xlabel('Category')
ax[0].set_ylabel('Days since prior order')
ax[0].set_xticklabels(labels = dept_list,rotation=60)
sns.countplot(df['category'],hue = df['cost'],ax=ax[1])
ax[1].set_title('Distribution of cost for category')
ax[1].set_xticklabels(labels = dept_list,rotation=60)
for p in ax[1].patches:
    ax[1].annotate(p.get_height(),(p.get_x(),p.get_height()+5))
sns.countplot(df['category'],hue = df['reorder'],ax=ax[2])
ax[2].set_title('Comparison of customer reorder to present')
ax[2].set_xticklabels(labels = dept_list,rotation=60)
for p in ax[2].patches:
    ax[2].annotate(p.get_height(),(p.get_x(),p.get_height()+5))
ax[3].bar(dept_list,yrs_spent)
ax[3].set_title('Days since prior order')
ax[3].set_xlabel('Category')
ax[3].set_ylabel('Days count')
ax[3].set_xticklabels(labels = dept_list,rotation=60)    
fig.tight_layout(pad=2.0)


#plt.show()
# Out:
# <ipython-input-32-4fd3ffc4b71e>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(labels = dept_list,rotation=60)
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <ipython-input-32-4fd3ffc4b71e>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[3].set_xticklabels(labels = dept_list,rotation=60)

# %%
sub_df = df.groupby('days_since_prior_order').mean()
sub_df
# Out:
#                          reorder  satisfaction_level  discount_rate  \
# days_since_prior_order
# 2                       0.016338            0.697078       0.717596
# 3                       0.246159            0.626314       0.668721
# 4                       0.348064            0.467517       0.767927
# 5                       0.565807            0.610495       0.813711
# 6                       0.291086            0.603440       0.754875
# 7                       0.000000            0.635957       0.682766
# 8                       0.000000            0.665062       0.711975
# 10                      0.000000            0.655327       0.731495
#
#                         number_order  reward_point  complaint   pick_up
# days_since_prior_order
# 2                           3.687423    200.133169   0.172010  0.016646
# 3                           3.327798    186.632935   0.138910  0.020798
# 4                           4.627689    223.455221   0.124364  0.013688
# 5                           4.519674    222.982361   0.116689  0.011533
# 6                           4.213092    212.051532   0.149025  0.023677
# 7                           3.851064    200.744681   0.138298  0.191489
# 8                           3.777778    193.802469   0.271605  0.061728
# 10                          3.682243    199.224299   0.233645  0.074766

# %%
sns.pointplot(sub_df.index,sub_df['reorder'])
# Out:
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='days_since_prior_order', ylabel='reorder'>

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,6)

# Convert these variables into categorical variables
df["category"] = df["category"].astype('category').cat.codes
df["cost"] = df["cost"].astype('category').cat.codes

# Create train and test splits
target_name = 'reorder'
X = df.drop('reorder', axis=1)


y=df[target_name]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.15, random_state=123, stratify=y)

dtree = tree.DecisionTreeClassifier(
    #max_depth=3,
    class_weight="balanced",
    min_weight_fraction_leaf=0.01
    )
dtree = dtree.fit(X_train,y_train)

## plot the importances ##
importances = dtree.feature_importances_
feat_names = df.drop(['reorder'],axis=1).columns


indices = np.argsort(importances)[::-1]
plt.figure(figsize=(12,6))
plt.title("Feature importances by DecisionTreeClassifier")
plt.bar(range(len(indices)), importances[indices], color='lightblue',  align="center")
plt.step(range(len(indices)), np.cumsum(importances[indices]), where='mid', label='Cumulative')
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical',fontsize=14)
plt.xlim([-1, len(indices)])
plt.show()

# %% [markdown]
# Logistic Regression V.S. Random Forest V.S. Decision Tree V.S. AdaBoost Model

# %%
# Compare the Logistic Regression Model V.S. Base Rate Model V.S. Random Forest Model
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier

# Create base rate model
def base_rate_model(X) :
    y = np.zeros(X.shape[0])
    return y

print ("---Base Model---")
base_roc_auc = roc_auc_score(y_test, base_rate_model(X_test))
print ("Base Rate AUC = %2.2f" % base_roc_auc)
print(classification_report(y_test, base_rate_model(X_test)))

# NOTE: By adding in "class_weight = balanced", the Logistic Auc increased by about 10%! This adjusts the threshold value
logis = LogisticRegression(class_weight = "balanced")
logis.fit(X_train, y_train)
print ("\n\n ---Logistic Model---")
logit_roc_auc = roc_auc_score(y_test, logis.predict(X_test))
print ("Logistic AUC = %2.2f" % logit_roc_auc)
print(classification_report(y_test, logis.predict(X_test)))

# Decision Tree Model
dtree = tree.DecisionTreeClassifier(
    #max_depth=3,
    class_weight="balanced",
    min_weight_fraction_leaf=0.01
    )
dtree = dtree.fit(X_train,y_train)
print ("\n\n ---Decision Tree Model---")
dt_roc_auc = roc_auc_score(y_test, dtree.predict(X_test))
print ("Decision Tree AUC = %2.2f" % dt_roc_auc)
print(classification_report(y_test, dtree.predict(X_test)))

# Random Forest Model
rf = RandomForestClassifier(
    n_estimators=1000, 
    max_depth=None, 
    min_samples_split=10, 
    class_weight="balanced"
    #min_weight_fraction_leaf=0.02 
    )
rf.fit(X_train, y_train)
print ("\n\n ---Random Forest Model---")
rf_roc_auc = roc_auc_score(y_test, rf.predict(X_test))
print ("Random Forest AUC = %2.2f" % rf_roc_auc)
print(classification_report(y_test, rf.predict(X_test)))


# Ada Boost
ada = AdaBoostClassifier(n_estimators=400, learning_rate=0.1)
ada.fit(X_train,y_train)
print ("\n\n ---AdaBoost Model---")
ada_roc_auc = roc_auc_score(y_test, ada.predict(X_test))
print ("AdaBoost AUC = %2.2f" % ada_roc_auc)
print(classification_report(y_test, ada.predict(X_test)))
# Out:
# ---Base Model---
# Base Rate AUC = 0.50
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      1714
#            1       0.00      0.00      0.00       536
#
#     accuracy                           0.76      2250
#    macro avg       0.38      0.50      0.43      2250
# weighted avg       0.58      0.76      0.66      2250
#
#
#
#  ---Logistic Model---
# Logistic AUC = 0.77
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.82      1714
#            1       0.49      0.80      0.61       536
#
#     accuracy                           0.76      2250
#    macro avg       0.71      0.77      0.72      2250
# weighted avg       0.82      0.76      0.77      2250
#
#
#
#  ---Decision Tree Model---
# Decision Tree AUC = 0.94
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1714
#            1       0.92      0.91      0.92       536
#
#     accuracy                           0.96      2250
#    macro avg       0.95      0.94      0.94      2250
# weighted avg       0.96      0.96      0.96      2250
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\peter\anaconda3\envs\Python 38\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  ---Random Forest Model---
# Random Forest AUC = 0.98
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1714
#            1       0.99      0.96      0.98       536
#
#     accuracy                           0.99      2250
#    macro avg       0.99      0.98      0.98      2250
# weighted avg       0.99      0.99      0.99      2250
#
#
#
#  ---AdaBoost Model---
# AdaBoost AUC = 0.92
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1714
#            1       0.91      0.88      0.89       536
#
#     accuracy                           0.95      2250
#    macro avg       0.94      0.92      0.93      2250
# weighted avg       0.95      0.95      0.95      2250

# %% [markdown]
# ROC Graph

# %%
# Create ROC Graph
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, logis.predict_proba(X_test)[:,1])
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
dt_fpr, dt_tpr, dt_thresholds = roc_curve(y_test, dtree.predict_proba(X_test)[:,1])
ada_fpr, ada_tpr, ada_thresholds = roc_curve(y_test, ada.predict_proba(X_test)[:,1])

plt.figure()

# Plot Logistic Regression ROC
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)

# Plot Random Forest ROC
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % rf_roc_auc)

# Plot Decision Tree ROC
plt.plot(dt_fpr, dt_tpr, label='Decision Tree (area = %0.2f)' % dt_roc_auc)

# Plot AdaBoost ROC
plt.plot(ada_fpr, ada_tpr, label='AdaBoost (area = %0.2f)' % ada_roc_auc)

# Plot Base Rate ROC
plt.plot([0,1], [0,1],label='Base Rate' 'k--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Graph')
plt.legend(loc="lower right")
plt.show()
